# %%
#1st Way:
print("Click Here to see the Final Data [https://drive.google.com/file/d/1-15pEvcqcn0kDPmyhiloPJdxpp735hcQ/view?usp=sharing]")
# Out:
# Click Here to see the Final Data [https://drive.google.com/file/d/1-15pEvcqcn0kDPmyhiloPJdxpp735hcQ/view?usp=sharing]

# %%
#2nd way
import selenium
from selenium import webdriver
driver = webdriver.firefox()
driver.get("/content/gdrive/My Drive/Colab_Notebooks/Solved Problems/Hexa to Dec/FinalData.xlsx")
element = driver.find_element_by_link_text("Click Here")
element.Click()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-e57992d898a4> in <module>()
#       1 #2nd way
# ----> 2 import selenium
#       3 from selenium import webdriver
#       4 driver = webdriver.firefox()
#       5 driver.get("/content/gdrive/My Drive/Colab_Notebooks/Solved Problems/Hexa to Dec/FinalData.xlsx")
#
# ModuleNotFoundError: No module named 'selenium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#3rd Way
#Import the required libraries
import tkinter as tk
from tkinter import *
import webbrowser

win = tk.Tk()

#Define a callback function
def callback(url):
   webbrowser.open_new_tab(url)

#Create a Label to display the link
link = Label(win, text="Click to se the New File")
link.pack()
link.bind("<Button-1>", lambda e:callback("https://drive.google.com/file/d/1-15pEvcqcn0kDPmyhiloPJdxpp735hcQ/view?usp=sharing"))

win.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-15-d448d04b84a8> in <module>()
#       5 import webbrowser
#       6
# ----> 7 win = tk.Tk()
#       8
#       9 #Define a callback function
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
hyperlink_format = '<a href="{https://drive.google.com/file/d/1-15pEvcqcn0kDPmyhiloPJdxpp735hcQ/view?usp=sharing}">{Link}</a>'

# %%
link_text = hyperlink_format.format

# %%
print(link_text)
# Out:
# <built-in method format of str object at 0x7ff11f1dcc10>
