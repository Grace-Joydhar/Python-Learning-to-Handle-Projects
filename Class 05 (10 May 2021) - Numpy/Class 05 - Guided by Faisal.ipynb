# %%
import numpy as np

a=np.array([2,4,5,6,7,8,11,3,9])
a
# Out:
# array([ 2,  4,  5,  6,  7,  8, 11,  3,  9])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.size
# Out:
# 9

# %%
a.itemsize
# Out:
# 8

# %%
a>10
# Out:
# array([False, False, False, False, False, False,  True, False, False])

# %%
a==2
# Out:
# array([ True, False, False, False, False, False, False, False, False])

# %%
a.max()
# Out:
# 11

# %%
a.min()
# Out:
# 2

# %%
b=np.arange(1,6,2)*2
print(b)
# Out:
# [ 2  6 10]

# %%
d=np.add(b,2)
d
# Out:
# array([ 4,  8, 12])

# %%
c=np.arange(1,6,2)
print(c)
# Out:
# [1 3 5]

# %%
np.add(b,c)
# Out:
# array([ 3,  9, 15])

# %%
print(d)
# Out:
# [ 4  8 12]

# %%
f=np.array([[1,2,3],[4,5,6]])
f.shape
# Out:
# (2, 3)

# %%
g=f.reshape(6)
g
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.power(c,3)
# Out:
# array([  1,  27, 125])

# %%
g[:]
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
g[2:4:2]
# Out:
# array([3])

# %%
g[::2]
# Out:
# array([1, 3, 5])

# %%
f
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
f[1,0:2]
# Out:
# array([4, 5])

# %%
f.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])
