# %% [markdown]
# LIST

# %%
a=[]
b=[1,2,3,"abc",3.5,True]
print(a)
print(b)
# Out:
# []
# [1, 2, 3, 'abc', 3.5, True]

# %%
print(b[3])
# Out:
# abc

# %%
print(b.index(6))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9a8c715b9a4e> in <module>()
# ----> 1 print(b.index(6))
#
# ValueError: 6 is not in list

# %%
b[-2]
# Out:
# 3.5

# %%
b[0:2]
# Out:
# [1, 2]

# %%
b[1:5]
# Out:
# [2, 3, 'abc', 3.5]

# %%
b[1:]
# Out:
# [2, 3, 'abc', 3.5, True]

# %%
b[:3]
# Out:
# [1, 2, 3]

# %%
b[-5:-2]
# Out:
# [2, 3, 'abc']

# %%
b.append(False)
print(b)
# Out:
# [1, 2, 3, 'abc', 3.5, True, False, False, False]

# %%
b.remove(False)

# %%
print(b)
# Out:
# [1, 2, 3, 'abc', 3.5, True]

# %%
b.append(False)

# %%
b.append(5)
b.append(False)
print(b)
# Out:
# [1, 2, 3, 'abc', 3.5, True, False, 5, 5, False]

# %%
b.remove(False)
print(b)
# Out:
# [1, 2, 3, 'abc', 3.5, True, 5, 5, False]

# %%
b.extend([True,2,23])
print(b)
# Out:
# [1, 2, 3, 'abc', 3.5, True, 5, 5, False, True, True, 2, 23]

# %%
b+=[1,2,3]

# %%
print(b)
# Out:
# [1, 2, 3, 'abc', 3.5, True, 5, 5, False, True, True, 2, 23, 1, 2, 3]

# %%
b.insert(1,100)
print(b)
# Out:
# [1, 100, 2, 3, 'abc', 3.5, True, 5, 5, False, True, True, 2, 23, 1, 2, 3]

# %%
b.count(2)
# Out:
# 3

# %%
a+=[1,2,5,3,7,6,8,10,9]

# %%
a.sort()
print(a)
# Out:
# [1, 1, 2, 2, 3, 3, 5, 5, 6, 6, 7, 7, 8, 8, 9, 9, 10, 10]

# %%
a.reverse()
print(a)
# Out:
# [10, 10, 9, 9, 8, 8, 7, 7, 6, 6, 5, 5, 3, 3, 2, 2, 1, 1]

# %%
ab=a.copy()
print(ab)
# Out:
# [1, 1, 2, 2, 3, 3, 5, 5, 6, 6, 7, 7, 8, 8, 9, 9, 10, 10]

# %%
ab.clear()
print(ab)
# Out:
# []

# %%
for i in b:
  print(i)
# Out:
# 1
# 2
# 3
# 100
# abc
# 3.5
# True
# 5
# 5
# False
# True
# True
# 2
# 23
# 1
# 2
# 3

# %%
d2=[[1,2,3],
    [4,5,6]]
print(d2)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
d2[0][1]
# Out:
# 2

# %% [markdown]
# TUPLE

# %%
t1=(1,2,3,"abc",True,[1,[2,4,6],3])
print(t1)
# Out:
# (1, 2, 3, 'abc', True, [1, [2, 4, 6], 3])

# %%
t1[5][1][2]
# Out:
# 6

# %%
len(t1)
# Out:
# 6

# %% [markdown]
# Dictionary

# %%
d={'a':2,'b':3}

print(d['a'])
# Out:
# 2

# %%
d.get('a')
# Out:
# 2

# %%
d.pop('b')
print(d)
# Out:
# {'a': 2}

# %%
'a'in d
# Out:
# True

# %%
x=list(d.keys())
print(x)
# Out:
# ['a', 'b']

# %%
if(('a'in d)==True):
  print(d['a'])
# Out:
# 2

# %%
y=list(d.values())
print(y)
# Out:
# [2, 3]

# %%
xy=list(d.items())
print(xy)
# Out:
# [('a', 2), ('b', 3)]

# %%
d['c']='abc'
print(d)
# Out:
# {'a': 2, 'b': 3, 'c': 'abc'}

# %%
del d['c']
print(d)
# Out:
# {'a': 2, 'b': 3}
