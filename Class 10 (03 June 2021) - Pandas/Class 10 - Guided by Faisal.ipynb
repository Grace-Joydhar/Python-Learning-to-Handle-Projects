# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('iris.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-9ec4ff0f085e> in <module>()
# ----> 1 df=pd.read_csv('iris.csv')
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
counts=df.species.value_counts()
print(counts)
# Out:
# versicolor    50
# virginica     50
# setosa        49
# 5.5            1
# Name: species, dtype: int64

# %%
df.sepal_length.max()
# Out:
# 7.9

# %%
df['sepal_length'].max()
# Out:
# 7.9

# %%
df.isnull().sum()
# Out:
# sepal_length    1
# sepal_width     1
# petal_length    0
# petal_width     1
# species         0
# dtype: int64

# %%
df.insert(3,'abc',3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22e4c94c7026> in <module>()
# ----> 1 df.insert(3,'abc',3)
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#      sepal_length  sepal_width  2  abc  ...  2  petal_length  petal_width    species
# 0             5.1          3.5  2    3  ...  2           1.4          NaN     setosa
# 1             4.9          3.0  2    3  ...  2           1.4          0.2     setosa
# 2             4.7          3.2  2    3  ...  2           1.3          0.2     setosa
# 3             NaN          3.1  2    3  ...  2           1.5          0.2        5.5
# 4             5.0          3.6  2    3  ...  2           1.4          0.2     setosa
# ..            ...          ... ..  ...  ... ..           ...          ...        ...
# 145           6.7          3.0  2    3  ...  2           5.2          2.3  virginica
# 146           6.3          2.5  2    3  ...  2           5.0          1.9  virginica
# 147           6.5          3.0  2    3  ...  2           5.2          2.0  virginica
# 148           6.2          3.4  2    3  ...  2           5.4          2.3  virginica
# ...

# %%
df.add(1) sub(), mul() , div()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ...

# %%
df.species.unique()
# Out:
# array(['setosa', '5.5', 'versicolor', 'virginica'], dtype=object)

# %%
df.columns
# Out:
# Index(['sepal_length',  'sepal_width',              2,          'abc',
#                     2,              2, 'petal_length',  'petal_width',
#             'species'],
#       dtype='object')

# %%
df.shape
# Out:
# (150, 9)

# %%
df1=df.copy()
df1
# Out:
#      sepal_length  sepal_width  2  abc  ...  2  petal_length  petal_width    species
# 0             5.1          3.5  2    3  ...  2           1.4          NaN     setosa
# 1             4.9          3.0  2    3  ...  2           1.4          0.2     setosa
# 2             4.7          3.2  2    3  ...  2           1.3          0.2     setosa
# 3             NaN          3.1  2    3  ...  2           1.5          0.2        5.5
# 4             5.0          3.6  2    3  ...  2           1.4          0.2     setosa
# ..            ...          ... ..  ...  ... ..           ...          ...        ...
# 145           6.7          3.0  2    3  ...  2           5.2          2.3  virginica
# 146           6.3          2.5  2    3  ...  2           5.0          1.9  virginica
# 147           6.5          3.0  2    3  ...  2           5.2          2.0  virginica
# 148           6.2          3.4  2    3  ...  2           5.4          2.3  virginica
# ...

# %%
df.iat[4,0]
# Out:
# 5.0
