# %%
def print1():
  print("hello world")

print1()
# Out:
# hello world

# %%
def sum(a,b):
  return a+b

x=sum(2,3)

print(x)
# Out:
# 5

# %%
def sum(a,b):
  print(a+b)

sum(2,3)
# Out:
# 5

# %%
def print2(a=3):
  print(a*10)

print2(5)
# Out:
# 50

# %%
def change(value):
 value = 2
 
val = 1
change(val)
print(val)
# Out:
# 1
