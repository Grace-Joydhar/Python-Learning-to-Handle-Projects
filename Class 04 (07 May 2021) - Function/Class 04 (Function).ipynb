# %% [markdown]
# A function is a block of organized, reusable code that is used to perform a single, related action. Functions provide better modularity for your application and a high degree of code reusing.
#
# There are two types of function:
# 1. Built in (print, append, join, extend, remove, copy......)
# 2.User defined (created by the user)
#
# How to write a function:
# def function_name ( ):
# def means defined and then the user defined function name
# () - it's called parentheses and we pass arguments through the parentheses.
#
# **Note:** By using 'return' function we can store the value for further use.

# %%
def myFunc(x):
  print("hello world + :",x)
myFunc(10)
# Out:
# hello world + : 10

# %%
def myfunc(x,y):
  return x+y

z= myfunc(5,10)
print(z)
# Out:
# 15

# %% [markdown]
# **Default Parameter value:**

# %%
def multi(x=3):
  print(x*10)
multi(5) #this is a default value
multi(6) #this is a default value
multi(7) #this is a default value
# Out:
# 50
# 60
# 70

# %% [markdown]
# **Keyword Arguments**
#
# You can also send arguments with the key = value syntax. This way the order of the arguments does not matter.

# %%
def keyvalue(child1, child2, child3):
  print("Youngest child name is: ", child3)
keyvalue(child1 = 'abc', child2 = 'def', child3 = 'ghi')
# Out:
# Youngest child name is:  ghi

# %% [markdown]
# **Number of Arguments**
# By default, a function must be called with the correct number of arguments. Meaning that if your function expects 2 arguments, you have to call the function with 2 arguments, not more, and not less.

# %%
def number_of_args(fname, lname):
  print("My name is:", fname , "\nAnd nick name is:", lname)
number_of_args('ABC', 'XYZ')
# Out:
# My name is: ABC
# And nick name is: XYZ

# %% [markdown]
# We can solve this problem with *args
#
# Arbitrary Arguments, *args:
#
# If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
#
# This way the function will receive a tuple of arguments, and can access the items accordingly:

# %%
def arbitaryFunc(*baby):
  print("The younger baby is: ", baby[2])
arbitaryFunc('MNO', 'PQR', 'UVW')
# Out:
# The younger baby is:  UVW

# %% [markdown]
# **Arbitrary Keyword Arguments, kwargs**
# If you do not know how many keyword arguments that will be passed into your function, add two asterisk: ** before the parameter name in the function definition.

# %%
def keyvalue(**kid):
  print("Youngest child name is: ", kid['fname'])
keyvalue(fname = 'abc',lname = 'ghi')
# Out:
# Youngest child name is:  abc

# %% [markdown]
# **Passing a List as an Argument**
# You can send any data types of argument to a function (string, number, list, dictionary etc.), and it will be treated as the same data type inside the function.

# %%
def myfood(food):
  for fruit_list in food: #for fruits in fruit_list:
    print(fruit_list) #print(fruits)

fruit_list = ['mango', 'apple', 'jackfruit']
myfood(fruit_list) #fruits
# Out:
# mango
# apple
# jackfruit

# %% [markdown]
# **The pass Statement**
# function definitions cannot be empty, but if you for some reason have a function definition with no content, put in the pass statement to avoid getting an error.

# %%
def passFunc():
  pass

# %% [markdown]
# **Recursion**
# Recursion function, which means a defined function can call itself. But the limit is 1000 times, so we need to define the expecting limit of ours.
#
# **Concept not clear**

# %%
def rec(i):
  if i>0:
    result = i + rec(i-1)
    print(result)
  else:
    result = 0
  return result
print("result is: ")
rec(5)

#Result could be 1, 3, 5, 9, 17 ....
# Out:
# result is:
# 1
# 3
# 6
# 10
# 15
# 15
