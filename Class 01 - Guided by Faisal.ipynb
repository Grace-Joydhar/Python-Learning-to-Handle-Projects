# %%
print(7)
# Out:
# 7

# %% [markdown]
# This is class1

# %%
print("hjdfhjdsf")
# Out:
# hjdfhjdsf

# %%
i=0
type(i)
# Out:
# 0

# %%
2**2
# Out:
# 4

# %%
7//4
# Out:
# 1

# %%
7/4
# Out:
# 1.75

# %%
x=23
y=23

# %%
x>y
# Out:
# False

# %%
x>=y
# Out:
# True

# %%
1 <= x <= 24
# Out:
# True

# %%
print("jsdaasjd\\\\")
# Out:
# jsdaasjd\\

# %% [markdown]
# Man is "mortal"

# %%
print('Man is "mortal"')
# Out:
# Man is "mortal"

# %%
print("Man is \"mortal\"")
# Out:
# Man is "mortal"

# %%
i=int(0)

print("this is the value of i=",i)
# Out:
# this is the value of i= 0

# %%
i =2.3030000033
print("this is the value of i=%0.2f"%i)
# Out:
# this is the value of i=2.30

# %%
a=int(input("insert a number: "))
print(a)
# Out:
# insert a number: sd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-3947067fe675> in <module>()
# ----> 1 a=int(input("insert a number: "))
#       2 print(a)
#
# ValueError: invalid literal for int() with base 10: 'sd'

# %%
a,b=input().split()
print(a,b)
# Out:
# 2 3
# 2 3

# %%
print("afhdaskjaskjd \
kasjdkasdjkasjdkasd")
# Out:
# afhdaskjaskjd kasjdkasdjkasjdkasd

# %%
print("kasjdkas",end="")
print("jkasjdas")
# Out:
# kasjdkasjkasjdas

# %% [markdown]
# Data type
# int: integer number
# float: decimal
# string: all
# boolean: true/false

# %%
i=bool(0)
print(i)
print(2>3)
# Out:
# False
# False

# %%
a=0
a+=3 # a=a+3

# %%
a="aksdjaskdj" +"kasjdkasjd"
print(a)
# Out:
# aksdjaskdjkasjdkasjd

# %%
1<5 or 1>4
# Out:
# True

# %%
# Out:
# 1

# %%
2 & 1
# Out:
# 0

# %%
2 | 1
# Out:
# 3

# %%
2^1
# Out:
# 3

# %%
4<<1
# Out:
# 8

# %%
8<<2
# Out:
# 32

# %%
4<<3
# Out:
# 32

# %%
8**2
# Out:
# 64
